# %% [markdown]
# ## Segmentation and Clustering_ Part 3

# %%
from bs4 import BeautifulSoup
import requests

url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')  



datasoup = soup.find('table')
#print(datasoup)

# %%
type(datasoup)
# Out:
# bs4.element.Tag

# %% [markdown]
# ## Data Scraping

# %%
  
Borough=[]   
Neighborhood=[]
Postalcode=[]
    
for row in datasoup.find_all('tr'):
     for cell in row.find_all('td'):
            if (cell.find('i') ):
                continue
            postalcode=cell.find('b').text
            Postalcode.append(postalcode)
            bor=cell.find('span').text.split("\n")[0]
            Borough.append(bor)
            neigh=cell.find('span').text.split("\n")[1:]
            lastneigh = ','.join(map(str, neigh))
            Neighborhood.append(lastneigh)

# %% [markdown]
# ## Clear Data

# %%
clearneighborhood=[]
cleanerneighborhood=[]
beautyneighborhood=[]

#print(neighborhood)

for j in Neighborhood:
        b=j.strip('()')
        cleanerneighborhood.append(b)

#print(cleanerneighborhood)



for j in cleanerneighborhood:
        b=j.replace('/',',')
        clearneighborhood.append(b)
        
        
clearneighborhood[4]=clearneighborhood[4] +"Queen's Park"      
#print(len(clearneighborhood))


for j in clearneighborhood:
        b=j.replace('(','').replace(')','')
        beautyneighborhood.append(b)


print("The length of Postalcode is : " , len(Postalcode))
print("The length of Borough is : ", len(Borough))
print("The length of Neighborhood is : " ,len(beautyneighborhood))
# Out:
# The length of Postalcode is :  103
# The length of Borough is :  103
# The length of Neighborhood is :  103

# %% [markdown]
# ## Create Dataframe

# %%
import pandas as pd 

data_dict={'Postalcode': Postalcode , 'Borough': Borough ,'Neighborhood': beautyneighborhood }

df=pd.DataFrame(data_dict)

# %%
df = df[['Postalcode','Borough','Neighborhood']]
df
# Out:
#     Postalcode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# 30         M5H  Downtown Toronto
# 31         M6H      West Toronto
# 32         M1J       Scarborough
# 33         M2J        North York
# 34         M3J        North York
# 35         M4J         East York
# 36         M5J  Downtown Toronto
# 37         M6J      West Toronto
# 38         M1K       Scarborough
# 39         M2K        North York
# 40         M3K        North York
# 41         M4K      East Toronto
# 42         M5K  Downtown Toronto
# 43         M6K      West Toronto
# 44         M1L       Scarborough
# 45         M2L        North York
# 46         M3L        North York
# 47         M4L      East Toronto
# 48         M5L  Downtown Toronto
# 49         M6L        North York
# 50         M9L        North York
# 51         M1M       Scarborough
# 52         M2M        North York
# 53         M3M        North York
# 54         M4M      East Toronto
# 55         M5M        North York
# 56         M6M              York
# 57         M9M        North York
# 58         M1N       Scarborough
# 59         M2N        North York
# 60         M3N        North York
# 61         M4N   Central Toronto
# 62         M5N   Central Toronto
# 63         M6N              York
# 64         M9N              York
# 65         M1P       Scarborough
# 66         M2P        North York
# 67         M4P   Central Toronto
# 68         M5P   Central Toronto
# 69         M6P      West Toronto
# 70         M9P         Etobicoke
# 71         M1R       Scarborough
# 72         M2R        North York
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4                                         Queen's Park
# 5                                     Islington Avenue
# 6                                      Malvern , Rouge
# 7                                      Don Mills,North
# 8                     Parkview Hill , Woodbine Gardens
# 9                             Garden District, Ryerson
# 10                                           Glencairn
# 11   West Deane Park , Princess Gardens , Martin Gr...
# 12            Rouge Hill , Port Union , Highland Creek
# 13                     Don Mills,South,Flemingdon Park
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Eringate , Bloordale Gardens , Old Burnhamthor...
# 18                 Guildwood , Morningside , West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28   Bathurst Manor , Wilson Heights , Downsview North
# 29                                    Thorncliffe Park
# 30                          Richmond , Adelaide , King
# 31                       Dufferin , Dovercourt Village
# 32                                 Scarborough Village
# 33                      Fairview , Henry Farm , Oriole
# 34                    Northwood Park , York University
# 35                      East Toronto,The Danforth,East
# 36   Harbourfront East , Union Station , Toronto Is...
# 37                           Little Portugal , Trinity
# 38       Kennedy Park , Ionview , East Birchmount Park
# 39                                     Bayview Village
# 40                          Downsview,East,CFB Toronto
# 41                       The Danforth West , Riverdale
# 42           Toronto Dominion Centre , Design Exchange
# 43      Brockton , Parkdale Village , Exhibition Place
# 44                   Golden Mile , Clairlea , Oakridge
# 45                           York Mills , Silver Hills
# 46                                      Downsview,West
# 47                     India Bazaar , The Beaches West
# 48                     Commerce Court , Victoria Hotel
# 49          North Park , Maple Leaf Park , Upwood Park
# 50                                       Humber Summit
# 51   Cliffside , Cliffcrest , Scarborough Village West
# 52                            Willowdale , Newtonbrook
# 53                                   Downsview,Central
# 54                                     Studio District
# 55                  Bedford Park , Lawrence Manor East
# 56   Del Ray , Mount Dennis , Keelsdale and Silvert...
# 57                                   Humberlea , Emery
# 58                        Birch Cliff , Cliffside West
# 59                                    Willowdale,South
# 60                                 Downsview,Northwest
# 61                                       Lawrence Park
# 62                                            Roselawn
# 63                      Runnymede , The Junction North
# 64                                              Weston
# 65   Dorset Park , Wexford Heights , Scarborough To...
# 66                                     York Mills West
# 67                                    Davisville North
# 68                            Forest Hill North & West
# 69                      High Park , The Junction South
# 70                                           Westmount
# 71                                  Wexford , Maryvale
# 72                                     Willowdale,West
# 73                                  North Toronto West
# 74               The Annex , North Midtown , Yorkville
# 75                             Parkdale , Roncesvalles
# 76   Canada Post Gateway Processing Centre,Enclave ...
# 77   Kingsview Village , St. Phillips , Martin Grov...
# 78                                           Agincourt
# 79                                          Davisville
# 80                     University of Toronto , Harbord
# 81                                 Runnymede , Swansea
# 82           Clarks Corners , Tam O'Shanter , Sullivan
# 83                        Moore Park , Summerhill East
# 84         Kensington Market , Chinatown , Grange Park
# 85   Milliken , Agincourt North , Steeles East , L'...
# 86   Summerhill West , Rathnelly , South Hill , For...
# 87   CN Tower , King and Spadina , Railway Lands , ...
# 88      New Toronto , Mimico South , Humber Bay Shores
# 89   South Steeles , Silverstone , Humbergate , Jam...
# 90                      Steeles West , L'Amoreaux West
# 91                                            Rosedale
# 92      Stn A PO Boxes,25 The Esplanade,Enclave of M5E
# 93                             Alderwood , Long Branch
# 94   Northwest,Clairville , Humberwood , Woodbine D...
# 95                                         Upper Rouge
# 96                        St. James Town , Cabbagetown
# 97             First Canadian Place , Underground city
# 98     The Kingsway , Montgomery Road , Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre,969 East...
# 101  Old Mill South , King's Mill Park , Sunnylea ,...
# 102  Mimico NW , The Queensway West , South of Bloo...

# %%
print("The size of the dataframe df is : " , df.shape)
# Out:
# The size of the dataframe df is :  (103, 3)

# %%
#***********************************************************

# %% [markdown]
# ## API Calls for Lat and Long

# %%
Latitude=[]
Longitude=[]  
# save your API key
API_key='AIzaSyCfOyzyLzO3gYKwmxsmIBuPY8jPDjX-3vs'

# %%
for post in Postalcode:
    # construct URL to make API call
    url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(API_key,post)
    response = requests.get(url).json() # get response
    if(len(response['results']) == 0 ):
            latitude=""
            longitude=""
            Latitude.append(latitude)
            Longitude.append(longitude)
            continue
    geographical_data = response['results'][0]['geometry']['location'] # get geographical coordinates
    latitude = geographical_data['lat']
    longitude = geographical_data['lng']
    Latitude.append(latitude)
    Longitude.append(longitude)

# %%
#Add Lat and Long to the dataframe
LL = pd.DataFrame({'Latitude': Latitude ,'Longitude': Longitude})
df=df.join(LL)

# %%
df_min=df.loc[df['Latitude'] != '']
df_min
# Out:
#     Postalcode           Borough  \
# 0          M3A        North York
# 2          M5A  Downtown Toronto
# 8          M4B         East York
# 13         M3C        North York
# 14         M4C         East York
# 18         M1E       Scarborough
# 20         M5E  Downtown Toronto
# 25         M6G  Downtown Toronto
# 27         M2H        North York
# 28         M3H        North York
# 30         M5H  Downtown Toronto
# 31         M6H      West Toronto
# 35         M4J         East York
# 36         M5J  Downtown Toronto
# 39         M2K        North York
# 40         M3K        North York
# 43         M6K      West Toronto
# 45         M2L        North York
# 46         M3L        North York
# 47         M4L      East Toronto
# 50         M9L        North York
# 51         M1M       Scarborough
# 52         M2M        North York
# 53         M3M        North York
# 54         M4M      East Toronto
# 57         M9M        North York
# 58         M1N       Scarborough
# 59         M2N        North York
# 61         M4N   Central Toronto
# 63         M6N              York
# 66         M2P        North York
# 72         M2R        North York
# 74         M5R   Central Toronto
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 84         M5T  Downtown Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 91         M4W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 99         M4Y  Downtown Toronto
# 102        M8Z         Etobicoke
#
#                                           Neighborhood Latitude Longitude
# 0                                            Parkwoods  32.3636  -90.1524
# 2                           Regent Park , Harbourfront  43.6543  -79.3606
# 8                     Parkview Hill , Woodbine Gardens  43.7149  -79.3051
# 13                     Don Mills,South,Flemingdon Park  45.5725   -73.414
# 14                                    Woodbine Heights  43.6953  -79.3184
# 18                 Guildwood , Morningside , West Hill  43.7636  -79.1887
# 20                                         Berczy Park  43.6448  -79.3733
# 25                                            Christie  43.6695  -79.4226
# 27                                   Hillcrest Village  43.7907  -79.3661
# 28   Bathurst Manor , Wilson Heights , Downsview North   40.782  -74.1386
# 30                          Richmond , Adelaide , King  43.6511  -79.3843
# 31                       Dufferin , Dovercourt Village   43.669  -79.4423
# 35                      East Toronto,The Danforth,East  43.6825  -79.3281
# 36   Harbourfront East , Union Station , Toronto Is...  43.6408  -79.3818
# 39                                     Bayview Village  41.6307  -93.7143
# 40                          Downsview,East,CFB Toronto  30.1212  -95.4403
# 43      Brockton , Parkdale Village , Exhibition Place  43.6368  -79.4282
# 45                           York Mills , Silver Hills  40.7459  -73.9839
# 46                                      Downsview,West  39.0941  -76.9338
# 47                     India Bazaar , The Beaches West  40.2665  -76.7463
# 50                                       Humber Summit  43.7563   -79.566
# 51   Cliffside , Cliffcrest , Scarborough Village West  36.3252  -79.6888
# 52                            Willowdale , Newtonbrook  40.7303  -73.9945
# 53                                   Downsview,Central  43.7238  -79.4899
# 54                                     Studio District  40.7379  -74.0002
# 57                                   Humberlea , Emery  43.7248  -79.5322
# 58                        Birch Cliff , Cliffside West  43.6927  -79.2648
# 59                                    Willowdale,South  40.7472  -73.8841
# 61                                       Lawrence Park   43.728  -79.3888
# 63                      Runnymede , The Junction North  43.6732  -79.4873
# 66                                     York Mills West  45.4852  -122.787
# 72                                     Willowdale,West  44.0693  -79.4817
# 74               The Annex , North Midtown , Yorkville  43.6727  -79.4057
# 78                                           Agincourt  43.7854  -79.2806
# 79                                          Davisville  43.4666  -81.1963
# 84         Kensington Market , Chinatown , Grange Park  45.4066  -71.9696
# 87   CN Tower , King and Spadina , Railway Lands , ...  43.6457  -79.3927
# 88      New Toronto , Mimico South , Humber Bay Shores  43.6056  -79.5013
# 89   South Steeles , Silverstone , Humbergate , Jam...  43.7394  -79.5884
# 91                                            Rosedale  43.6796  -79.3775
# 93                             Alderwood , Long Branch  43.6024  -79.5435
# 94   Northwest,Clairville , Humberwood , Woodbine D...  43.7067  -79.5941
# 99                                Church and Wellesley  43.6659  -79.3832
# 102  Mimico NW , The Queensway West , South of Bloo...  43.6288   -79.521

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.15.0                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Libraries imported.

# %%
latitude = 43.653908
longitude = -79.384293
print('The geograpical coordinate of Toronoto Canada are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronoto Canada are 43.653908, -79.384293.

# %%
#map of Toronto
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)


# Visualizing and adding markers to map
for lat, lng, borough, neighborhood in zip(df_min['Latitude'], df_min['Longitude'], df_min['Borough'], df_min['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
